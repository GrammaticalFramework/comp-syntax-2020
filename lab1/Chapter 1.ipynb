# %% [markdown]
# # Chapter 1 Submission
# ## Computational Syntax
# ### Spring 2020 Xiao Li

# %%
# import
import nltk
import pandas as pd
from nltk import FreqDist as fq

# %% [markdown]
# ### 3. The language I chose to compare with English is Chinese.

# %%
# open the conllu data and save all the tags in a list
file= open("/Users/xiaoli/Downloads/ud-treebanks-v2.5/UD_ENGLISH-PUD/en_pud-ud-test.conllu")
en_tags = []
en_lines = []
for line in file:
    line = line.split("\t")
    en_lines.append(line)
    if len(line)>=3:
        en_tags.append(line[3])
file.close()

# %%
# create a object of nltk.freqency_distribution
en_distribution = fq(en_tags)

# %% [markdown]
# ### The most frequent pos_tags in English are reported as the following:
# [('NOUN', 4040),
#  ('ADP', 2493),
#  ('PUNCT', 2451),
#  ('VERB', 2156),
#  ('DET', 2086),
#  ('PROPN', 1727),
#  ('ADJ', 1540),
#  ('PRON', 1021),
#  ('AUX', 1014),
#  ('ADV', 849)]

# %%
de_distribution.most_common(10)
# Out:
# [('NOUN', 4040),
#  ('ADP', 2493),
#  ('PUNCT', 2451),
#  ('VERB', 2156),
#  ('DET', 2086),
#  ('PROPN', 1727),
#  ('ADJ', 1540),
#  ('PRON', 1021),
#  ('AUX', 1014),
#  ('ADV', 849)]

# %% [markdown]
# ### plot visualization

# %%
en_distribution.plot()

# %% [markdown]
# ### Basically the same with Chinese

# %%
file= open("/Users/xiaoli/Downloads/ud-treebanks-v2.5/UD_Chinese-PUD/zh_pud-ud-test.conllu")
cn_tags = []
cn_lines = []
for line in file:
    line = line.split("\t")
    cn_lines.append(line)
    if len(line)>=3:
        cn_tags.append(line[3])
file.close()

# %%
cn_distribution = fq(cn_tags)

# %% [markdown]
# ### The most frequent pos_tags in Chinese are reported as the following:
# [('NOUN', 5410),
#  ('VERB', 3467),
#  ('PUNCT', 2902),
#  ('PART', 1881),
#  ('PROPN', 1361),
#  ('ADP', 1288),
#  ('ADV', 1283),
#  ('NUM', 873),
#  ('PRON', 710),
#  ('ADJ', 650)]

# %%
cn_distribution.most_common(10)
# Out:
# [('NOUN', 5410),
#  ('VERB', 3467),
#  ('PUNCT', 2902),
#  ('PART', 1881),
#  ('PROPN', 1361),
#  ('ADP', 1288),
#  ('ADV', 1283),
#  ('NUM', 873),
#  ('PRON', 710),
#  ('ADJ', 650)]

# %%
cn_distribution.plot()

# %% [markdown]
# ### Observations:
# #### a. Both langauges in the corpus consist mostly of nouns. The nouns contribute profoundly to the semantics, so the result is not suprising. Furthermore, nouns blong to closed pos class. The low grade of difference in terms of syntax can be also reasoned. It can be considered as the conrrenspondenses between the closed grammar classes is stronger. So simplified: a noun tends to be subtituted wiht a noun
# #### b. English has way more "DET", while Chinese as very few of "DET". This reflexes the language structrue. "The", is the most frequnt word in English while in Chinese, the word "这 (this)" and "那 (that)" even have the tendency to be adjactives.
# #### c. There are more punctuation in Chinese. This indicates shorter sentences and shorter sub-sentences.
# #### d. In Chinese, there are more verbs than in English. This shows that Chinese is pradicate-centered.

# %% [markdown]
# ### 5. The trees are drew as the following
# ![pic1](5.jpeg)

# %% [markdown]
# ### 6. The word alignments are drew as the following:
# ![pic2](6.jpeg)
# ### Observations:
# #### Both English and Chinses have SVO structrue. Alothough there are some speacial structures such as "there be" and "it is..." with "pseudo subject" which have no corresponding structrue. Some of the arguments for this kind of structure we often heard in school grammar is to avoid long subject, while Chinese language does not show this tendency.
# #### More than one components in one language can be linked to one components in another language.
